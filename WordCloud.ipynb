# %%
total = []
for n in tqdm(range(1, 3992, 10)):
    url = requests.get(f"https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%EA%B3%A0%EB%A0%A4%EB%8C%80&sort=0&photo=0&field=0&pd=0&ds=&de=&cluster_rank=112&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:r,p:all,a:all&start={n}")
    html = BeautifulSoup(url.text)
    news = html.find_all("a", class_ = 'news_tit')
    for i in news:
        total.append(i['title'])
    time.sleep(1)
# Out:
# 100%|██████████| 400/400 [15:07<00:00,  2.27s/it]

# %%
len(total)
# Out:
# 4000

# %%
import re # 정규표현식 // 어떤 문장이 있을때 내가 원하는 패턴을 추출

t = ""
for i in total:
    t += i
    t += " "

# %%
len(t)
# Out:
# 140686

# %%
# konlpy
words = re.findall("[가-힣]+", t)
len(words)
# Out:
# 30543

# %%
dic = {}
for i in words:
    if i not in dic:
        dic[i] = 1
    else:
        dic[i] += 1

dic
# Out:
# {'고려대안산병원': 30,
#  '신철민': 8,
#  '교수': 429,
#  '경기도지사': 8,
#  '표창': 38,
#  '이준석': 41,
#  '김경진': 18,
#  '고려대라': 2,
#  '동대문': 5,
#  '준거면': 2,
#  '난': 21,
#  '보스턴': 12,
#  '출마해야하나': 5,
#  '고려대': 2140,
#  '한국형': 2,
#  '온라인': 13,
#  '공개강좌': 1,
#  '신규': 8,
#  '강좌': 4,
#  '개강': 8,
#  '대입정시': 2,
#  '마감': 9,
#  '대': 120,
#  '성균관대': 19,
#  '이원준': 5,
#  '한국정보과학회장': 1,
#  '취임': 115,
#  '미래': 25,
#  '년': 101,
#  '기획': 2,
#  '서울대': 92,
#  '연구진': 10,
#  '췌장암': 10,
#  '유형': 1,
#  '판정': 1,
#  '기술': 56,
#  '개발': 129,
#  '한국정보과학회': 4,
#  '회장': 63,
#  '신현석': 2,
#  '한국교육학회': 2,
#  '푸드테크': 2,
#  '팜킷': 3,
#  '연구실과': 1,
#  '맞춤형': 9,
#  '식단': 2,
#  '사업': 17,
#  '협약': 78,
#  '부고': 50,
#  '이종선': 6,
#  '노동대학원': 10,
#  '씨': 39,
#  '부친상': 23,
#  '김운영': 10,
#  '안산병원': 11,
#  '병원장': 16,
#  '옥용식': 26,
#  '노준홍': 3,
#  '교수팀': 55,
#  '페로브스카이드': 3,
#  '태양전지의': 3,
#  '환경영향평가': 3,
#  '시스템': 22,
#  '구축': 49,
#  '정시경쟁률': 2,
#  '마감전날': 2,
#  '사이버국방': 4,
#  '등': 165,
#  '개': 75,
#  '미달': 9,
#  '임종인': 4,
#  '석좌교수': 5,
# ...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

plt.figure(figsize = (10, 10))

wc = WordCloud(background_color='white',
               font_path="BMDOHYEON_ttf.ttf",
               mask = img2)
cloud = wc.generate_from_frequencies(dic)

plt.imshow(cloud)

# %%
from PIL import Image
import numpy as np # 행렬

img = Image.open("하트.png")
img2 = np.array(img)
img2
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...
